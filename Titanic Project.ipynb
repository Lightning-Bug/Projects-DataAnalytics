# %%
import pandas as pd
from pandas import Series,DataFrame

# %%
titanic_df= pd.read_csv("train.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import numpy as np
import matplotlib.pyplot as lplt
import seaborn as sns
# %matplotlib inline

# %%
sns.factorplot('Sex',data=titanic_df,kind='count')

# %%
sns.factorplot('Sex',data=titanic_df,hue='Pclass',kind='count')

# %%
sns.factorplot('Pclass',data=titanic_df,hue='Sex',kind='count')

# %%
def male_female(passenger):
    age,sex=passenger
    
    if(age<16):
        return 'child'
    else:
        return sex

# %%
titanic_df['person']=titanic_df[['Age','Sex']].apply(male_female,axis=1)

# %%
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male
# 5      0            330877   8.4583   NaN        Q    male
# 6      0             17463  51.8625   E46        S    male
# 7      1            349909  21.0750   NaN        S   child
# 8      2            347742  11.1333   NaN        S  female
# 9      0            237736  30.0708   NaN        C   child

# %%
sns.factorplot('Pclass',data=titanic_df,kind='count',hue='person')

# %%
titanic_df['Age'].hist(bins=70)

# %%
titanic_df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
fig = sns.FacetGrid(titanic_df,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df,hue='person',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
fig = sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)

oldest = titanic_df['Age'].max()

fig.set(xlim=(0,oldest))

fig.add_legend()

# %%
deck = titanic_df['Cabin'].dropna()
deck.head()
# Out:
# 1      C85
# 3     C123
# 6      E46
# 10      G6
# 11    C103
# Name: Cabin, dtype: object

# %%
levels=[]

for level in deck:
    levels.append(level[0])
    
cabin_df = DataFrame(levels)
cabin_df.columns=['Cabin']
sns.factorplot('Cabin',data=cabin_df,palette='winter_d')

#can get color in matplotlib color documentation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-838a8fd44c90> in <module>()
#       6 cabin_df = DataFrame(levels)
#       7 cabin_df.columns=['Cabin']
# ----> 8 sns.factorplot('Cabin',data=cabin_df)
#       9
#      10 #can get color in matplotlib color documentation
#
# /home/parii/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3528
#    3529     # Draw the plot onto the facets
# -> 3530     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3531
#    3532     # Special case axis labels for a count type plot
#
# /home/parii/.local/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_dataframe(self, func, *args, **kwargs)
#     807
#     808             # Draw the plot
# --> 809             self._facet_plot(func, ax, args, kwargs)
#     810
#     811         # Finalize the annotations and layout
#
# /home/parii/.local/lib/python2.7/site-packages/seaborn/axisgrid.pyc in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     825
#     826         # Draw the plot
# --> 827         func(*plot_args, **plot_kwargs)
#     828
#     829         # Sort out the supporting information
#
# /home/parii/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3141                             estimator, ci, n_boot, units,
#    3142                             markers, linestyles, dodge, join, scale,
# -> 3143                             orient, color, palette, errwidth, capsize)
#    3144
#    3145     if ax is None:
#
# /home/parii/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize)
#    1667                                  order, hue_order, units)
#    1668         self.establish_colors(color, palette, 1)
# -> 1669         self.estimate_statistic(estimator, ci, n_boot)
#    1670
#    1671         # Override the default palette for single-color plots
#
# /home/parii/.local/lib/python2.7/site-packages/seaborn/categorical.pyc in estimate_statistic(self, estimator, ci, n_boot)
#    1480                     statistic.append(np.nan)
#    1481                 else:
# -> 1482                     statistic.append(estimator(stat_data))
#    1483
#    1484                 # Get a confidence interval for this estimate
#
# /home/parii/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    2907
#    2908     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2909                           out=out, **kwargs)
#    2910
#    2911
#
# /home/parii/.local/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      80             ret = ret.dtype.type(ret / rcount)
#      81     else:
# ---> 82         ret = ret / rcount
#      83
#      84     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
levels = []

for level in deck:
    levels.append(level[0])
    
cabin_df = DataFrame(levels)
cabin_df.columns = ['Cabin']
sns.factorplot('Cabin',data=cabin_df,palette='winter_d',kind='count')

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']
sns.factorplot('Cabin',data=cabin_df,palette='summer',kind='count')

# %%
sns.factorplot('Embarked',data=titanic_df,hue='Pclass',kind='count' )

# %%
# Now who is alone and who is with family

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male

# %%
titanic_df['alone']=titanic_df.SibSp + titanic_df.Parch

# %%
titanic_df['alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: alone, Length: 891, dtype: int64

# %%
titanic_df['alone'].loc[titanic_df['alone'] > 0] ='With Family'
titanic_df['alone'].loc[titanic_df['alone'] == 0] ='Alone'
# Out:
# /home/parii/.local/lib/python2.7/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        alone
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# 3      0            113803  53.1000  C123        S  female  With Family
# 4      0            373450   8.0500   NaN        S    male        Alone

# %%
sns.factorplot('alone',data=titanic_df,palette='Blues',kind='count')

# %%
titanic_df['Survivor'] = titanic_df.Survived.map({0:'no',1:'yes'})

sns.factorplot('Survivor',data=titanic_df,kind='count')

# %%
sns.factorplot('Pclass','Survived',hue='person',data=titanic_df)

# %%
sns.lmplot('Age','Survived',data=titanic_df)

# %%
sns.lmplot('Age','Survived',hue='Pclass',palette='winter',data=titanic_df)

# %%
generations = [10,20,40,60,80]

sns.lmplot('Age','Survived',hue='Pclass',data=titanic_df,
           palette='winter',x_bins=generations)

# %%
if (titanic_df['Cabin'] == 'Nan' ):
    deck=Null
else:
    deck=titanic_df['Cabin']
deck.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-f3b480ecd84b> in <module>()
# ----> 1 if (titanic_df['Cabin'] == 'Nan' ):
#       2     deck=Null
#       3 else:
#       4     deck=titanic_df['Cabin']
#       5 deck.head()
#
# /home/parii/.local/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
deckname = []

for level in deck:
    deckname.append(level[0])
    
dackname
